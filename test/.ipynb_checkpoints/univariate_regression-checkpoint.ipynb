# %%
#=r=1.7
t=11
l=Int64((t-1)/2)
X = zeros(Float64,t,1)
for j in 1:t
    X[j,1] = 2r*rand()-r
end=#

# %%
#=data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
output_file = open(data*"/univariate_regression_data.jl","w")

write(output_file, "r = $(r)")
write(output_file, "; \n \n")
write(output_file, "t = $(t)")
write(output_file, "; \n \n")
write(output_file, "X = ")
show(output_file, X)

close(output_file)=#

# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/univariate_regression_data.jl");

# %%
func(a)=sin(a)+0.2*cos(5*a)#*(2*rand().-1)
phi = Vector{Float64}(func.(X[:,1]))
# Out:
# 11-element Vector{Float64}:
#   1.1431952492161304
#  -0.8452488015471916
#   1.1532815661029898
#  -0.8630193070827001
#   0.2656425053690127
#   0.984051150134615
#  -1.097420738292923
#   0.9205142864077646
#   0.30689838561597627
#   0.4276335008420034
#  -0.8031016487449648

# %%
using Plots

#p_exact(z)=0.5
scatter(X[:,1], phi,label ="input data",color="Blue")#,aspect_ratio = 1)
plot!(func, -r, r, label ="exact",color="Red")

# %%
include("../src/RegressionModels.jl")
using .RegressionModels


n=1
c=Inf
k=3


eval_pol_approx=RegressionModels.model_pol_regress(n,X,t,c,k,phi,additional_monomials=false)
# Out:
# ****Method based on polynomial regression****
#
# number of attributes: n=1
# sample sizes for traint sets: t=11
# degree of separating polynomial: k=3
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 2
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.01
# (::Main.RegressionModels.var"#eval_pol_approx#316"{Int64, Vector{Float64}}) (generic function with 1 method)

# %%
p_approx(z)=eval_pol_approx([z;zeros(n-1)])
plot!(p_approx, -1.7, 1.7, label = "k = $(k)",#=legend=:bottomright,=#title = "t = $(t)",color="Orange")

# %%
include("../src/RegressionModels.jl")
using .RegressionModels


n=1
c=Inf
k=8


eval_pol_approx=RegressionModels.model_pol_regress(n,X,t,c,k,phi,additional_monomials=false)
# Out:
# ****Method based on polynomial regression****
#
# number of attributes: n=1
# sample sizes for traint sets: t=11
# degree of separating polynomial: k=8
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 10
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 7
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
# WARNING: replacing module RegressionModels.
# (::Main.RegressionModels.var"#eval_pol_approx#316"{Int64, Vector{Float64}}) (generic function with 1 method)

# %%
p_approx2(z)=eval_pol_approx([z;zeros(n-1)])
plot!(p_approx2, -1.7, 1.7, label = "k = $(k)",color="Green")

# %%
#savefig("/home/hoanganh/Desktop/math-topics/Polynomial_Regression/drafts/univariate_regression_numsamp$(t).png")
# Out:
# "/home/hoanganh/Desktop/math-topics/Polynomial_Regression/drafts/univariate_regression_numsamp11.png"
