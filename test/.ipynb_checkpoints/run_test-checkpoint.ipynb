# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets" # path of data
# Out:
# "/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets"

# %%
include("../src/RegressionModels.jl")
using .RegressionModels

RegressionModels.test()
# Out:
# Number of samples: 100
# Cardinality of train set: 80
# Cardinality of test set: 20
# ****Method based on polynomial regression****
#
# number of attributes: n=1
# sample sizes for traint sets: t=80
# degree of separating polynomial: k=3
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 2
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# ...

# %%
include("../src/RegressionModels.jl")
using .RegressionModels

RegressionModels.test_univariate_regression(data)
# Out:
# ****Method based on polynomial regression****
#
# number of attributes: n=1
# sample sizes for traint sets: t=11
# degree of separating polynomial: k=3
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 2
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# ...

# %%
include("../src/RegressionModels.jl")
using .RegressionModels

RegressionModels.test_univariate_regression2(data)
# Out:
# ****Method based on polynomial regression****
#
# number of attributes: n=1
# sample sizes for traint sets: t=41
# degree of separating polynomial: k=3
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 2
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# ...

# %%
include("../src/RegressionModels.jl")
using .RegressionModels

RegressionModels.test_univariate_classification_pol(data)
# Out:
# ****Method based on polynomial regression****
#
# number of attributes: n=1
# sample sizes for traint sets: t=[5, 5, 5, 5, 5, 5]
# degree of separating polynomial: k=5
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 7
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 4
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# ...

# %%
include("../src/RegressionModels.jl")
using .RegressionModels

RegressionModels.test_univariate_classification_pol2(data)
# Out:
# ****Method based on polynomial regression****
#
# number of attributes: n=1
# sample sizes for traint sets: t=[30, 30, 30, 30, 30, 30]
# degree of separating polynomial: k=5
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 7
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Eliminator started.
# Freed constraints in eliminator : 4
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
# ...

# %%
include("../src/RegressionModels.jl")
using .RegressionModels

RegressionModels.test_house_regression(data,1)
# Out:
# Number of samples: 506
# Cardinality of train set: 405
# Cardinality of test set: 101
# ****Method based on polynomial regression****
#
# number of attributes: n=13
# sample sizes for traint sets: t=405
# degree of separating polynomial: k=1
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 0
#   Affine conic cons.     : 1
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 15
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 12
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# ...

# %%
include("../src/RegressionModels.jl")
using .RegressionModels

RegressionModels.test_Breast_cancer_polynomial_regression(data,1)
# Out:
# WARNING: replacing module RegressionModels.
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /home/hoanganh/.julia/packages/CSV/1P1tQ/src/file.jl:576
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 2. Filling remaining columns with `missing`
# └ @ CSV /home/hoanganh/.julia/packages/CSV/1P1tQ/src/file.jl:576
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 3. Filling remaining columns with `missing`
# └ @ CSV /home/hoanganh/.julia/packages/CSV/1P1tQ/src/file.jl:576
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 4. Filling remaining columns with `missing`
# └ @ CSV /home/hoanganh/.julia/packages/CSV/1P1tQ/src/file.jl:576
# ┌ Warning: thread = 1 warning: only found 32 / 33 columns around data row: 5. Filling remaining columns with `missing`
# └ @ CSV /home/hoanganh/.julia/packages/CSV/1P1tQ/src/file.jl:576
# ...
